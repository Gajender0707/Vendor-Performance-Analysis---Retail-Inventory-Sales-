# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir("..")

# %%
data=pd.read_csv("data/vendor_df.csv")

# %%
data.head()
# Out:
#    Brand  VendorNumber  TotalPurchasePrice  TotalPurchaseQuantity  \
# 0     58          8320             5530.88                   3550
# 1     60         12546              717.80                   1633
# 2     61          8004              275.60                    312
# 3     62          1128            16255.89                   3200
# 4     63          1128            15961.04                   2855
#
#    TotalPurchaseDollars  VendorNo  TotalSalesDollars  TotalSalesQuantity  \
# 0               32944.0    8320.0           43341.54              3446.0
# 1               12084.2   12546.0           18716.25              1775.0
# 2                3307.2    8004.0            4364.88               312.0
# 3               91744.0    1128.0          119863.75              3125.0
# 4               86963.3    1128.0          112249.22              2778.0
#
#    ExciseTax                   VendorName  FreightCost  \
# 0    2715.12  SHAW ROSS INT L IMP LTD          3151.92
# 1    1398.56  JIM BEAM BRANDS COMPANY        123880.97
# 2     245.70  SAZERAC CO INC                  50293.62
# 3    2463.18  BROWN-FORMAN CORP               68601.68
# 4    2190.45  BROWN-FORMAN CORP               68601.68
#
#                    Description  PurchasePricePerUnit  ActualPricePerUnit
# 0  Gekkeikan Black & Gold Sake                  9.28               12.99
# 1       Canadian Club 1858 VAP                  7.40               10.99
# 2        Margaritaville Silver                 10.60               13.99
# 3     Herradura Silver Tequila                 28.67               36.99
# 4   Herradura Reposado Tequila                 30.46               38.99

# %%
data.shape
# Out:
# (12490, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12490 entries, 0 to 12489
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  12490 non-null  int64
#  1   VendorNumber           12490 non-null  int64
#  2   TotalPurchasePrice     12490 non-null  float64
#  3   TotalPurchaseQuantity  12490 non-null  int64
#  4   TotalPurchaseDollars   12490 non-null  float64
#  5   VendorNo               12281 non-null  float64
#  6   TotalSalesDollars      12281 non-null  float64
#  7   TotalSalesQuantity     12281 non-null  float64
#  8   ExciseTax              12281 non-null  float64
#  9   VendorName             12490 non-null  object
#  10  FreightCost            12490 non-null  float64
#  11  Description            12443 non-null  object
#  12  PurchasePricePerUnit   12443 non-null  float64
#  13  ActualPricePerUnit     12443 non-null  float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.3+ MB

# %%
data["VendorName"].unique()
## as we can here is a lot of extra white space avaible in the vendorname which we have to clean
# Out:
# array(['SHAW ROSS INT L IMP LTD    ', 'JIM BEAM BRANDS COMPANY    ',
#        'SAZERAC CO INC             ', 'BROWN-FORMAN CORP          ',
#        'ULTRA BEVERAGE COMPANY LLP ', 'PROXIMO SPIRITS INC.       ',
#        'MARTIGNETTI COMPANIES', 'MARTIGNETTI COMPANIES ',
#        'DIAGEO NORTH AMERICA INC   ', 'PERNOD RICARD USA          ',
#        'SAZERAC NORTH AMERICA INC. ', 'MOET HENNESSY USA INC      ',
#        'MCCORMICK DISTILLING CO    ', 'BACARDI USA INC            ',
#        'STOLI GROUP,(USA) LLC      ', 'CAMPARI AMERICA            ',
#        'HEAVEN HILL DISTILLERIES   ', 'WILLIAM GRANT & SONS INC   ',
#        'HOOD RIVER DISTILLERS, Inc.', 'BANFI PRODUCTS CORP        ',
#        'M S WALKER INC             ', 'STELLAR IMPORTING CO LLC   ',
#        'CONSTELLATION BRANDS INC   ', 'Serralles Usa LLC          ',
#        'LUXCO INC                  ', 'SURVILLE ENTERPRISES CORP  ',
#        'STATE WINE & SPIRITS   ', 'MHW LTD                    ',
#        'PERFECTA WINES             ', 'EDRINGTON AMERICAS         ',
#        'SEA BREEZE CELLARS LLC     ', 'PINE STATE TRADING CO      ',
#        'REMY COINTREAU USA INC     ', 'DISARONNO INTERNATIONAL LLC',
#        'KOBRAND CORPORATION        ', 'LABELLE VYDS AND WINERY    ',
#        'ADAMBA IMPORTS INTL INC    ', 'SIDNEY FRANK IMPORTING CO  ',
#        'CASTLE BRANDS CORP.        ', 'PHILLIPS PRODUCTS CO.      ',
#        'AAPER ALCOHOL & CHEMICAL CO', 'OLE SMOKY DISTILLERY LLC   ',
#        'WEIN BAUER INC             ', 'NICHE W & S                ',
#        'CHARLES JACQUIN ET CIE INC ', 'SOUTHERN GLAZERS W&S OF NE ',
#        'SOUTHERN WINE & SPIRITS NE ', 'WESTERN SPIRITS BEVERAGE CO',
#        'SMOKY QUARTZ DISTILLERY LLC', 'VINEDREA WINES LLC         ',
#        'FLAG HILL WINERY & VINEYARD', 'DUGGANS DISTILLED PRODUCTS ',
#        'PALM BAY INTERNATIONAL INC ', 'E & J GALLO WINERY         ',
#        'LAIRD & CO                 ', 'ATLANTIC IMPORTING COMPANY ',
#        'TRINCHERO FAMILY ESTATES   ', 'FREDERICK WILDMAN & SONS   ',
#        'BULLY BOY DISTILLERS       ', 'DJINN SPIRITS LLC          ',
#        'PARK STREET IMPORTS LLC    ', 'THE PIERPONT GROUP LLC     ',
#        'SWEETWATER FARM         ', 'CALEDONIA SPIRITS INC      ',
#        'STAR INDUSTRIES INC.       ', 'CAPSTONE INTERNATIONAL     ',
#        'TY KU LLC                  ', 'SEA HAGG DISTILLERY LLC    ',
#        'FORTUNE WINE BROKERS LLC   ', 'ALTAMAR BRANDS LLC         ',
#        'MARSALLE COMPANY           ', 'TAMWORTH DISTILLING        ',
#        'Russian Standard Vodka     ', 'BLACK PRINCE DISTILLERY INC',
#        'AMERICAN VINTAGE BEVERAGE  ', 'KLIN SPIRITS LLC           ',
#        'STARK BREWING COMPANY      ', 'TALL SHIP DISTILLERY LLC   ',
#        'FABRIZIA SPIRITS LLC       ', 'BLACK ROCK SPIRITS LLC     ',
#        'WINE GROUP INC             ', 'Circa Wines                ',
#        'BLACK COVE BEVERAGES       ', 'STE MICHELLE WINE ESTATES  ',
#        'DIAGEO CHATEAU ESTATE WINES', 'LAUREATE IMPORTS CO        ',
#        'MAJESTIC FINE WINES        ', 'TREASURY WINE ESTATES      ',
#        'VINEYARD BRANDS INC        ', 'VINEYARD BRANDS LLC        ',
#        'MANGO BOTTLING INC         ', 'PREMIER DISTRIBUTORS       ',
#        'PREMIUM PORT WINES, INC.   ', 'TAKARA SAKE USA INC        ',
#        'THE IMPORTED GRAPE LLC     ', 'VRANKEN AMERICA            ',
#        'DELICATO VINEYARDS INC     ', 'VINILANDIA USA             ',
#        'CRUSH WINES                ', 'CANDIA VINEYARDS           ',
#        'Dunn Wine Brokers          ', 'BRONCO WINE COMPANY        ',
#        'VINEXTRA INC               ', 'LATITUDE BEVERAGE COMPANY  ',
#        'R.P.IMPORTS INC            ', 'POVERTY LANE ORCHARDS      ',
#        'MOONLIGHT MEADERY          ', 'SWEET BABY VINEYARD        ',
#        'MILTONS DISTRIBUTING CO    ', 'JEWELL TOWNE VINEYARDS     ',
#        'HAUNTING WHISPER VYDS      ', 'ALISA CARR BEVERAGES           ',
#        'ZORVINO VINEYARDS          ', 'AMERICAN SPIRITS EXCHANGE  ',
#        'UNCORKED       ', 'PSP WINES ', 'INCREDIBREW INC            ',
#        'CENTEUR IMPORTS LLC        ', 'FULCHINO VINEYARD INC      ',
#        'HIGHLAND WINE MERCHANTS LLC', 'APPOLO VINEYARDS LLC       ',
#        'WALPOLE MTN VIEW WINERY    ', 'TRUETT HURST               ',
#        'GILMANTON WINERY & VINEYARD', 'LOYAL DOG WINERY           ',
#        'SILVER MOUNTAIN CIDERS     ', 'FANTASY FINE WINES CORP    ',
#        'IRA GOLDMAN AND WILLIAMS, LLP          ',
#        'FLAVOR ESSENCE INC         '], dtype=object)

# %%
#removing the extrawhite space from the data
data["VendorName"]=data["VendorName"].str.strip()
data["Description"]=data["Description"].str.strip()

# %%
## Now create the field which need for the further analysis
data["GrossProfit"]=data["TotalSalesDollars"]-data["TotalPurchaseDollars"]
data["ProfitMargin"]=round((data["GrossProfit"]/data["TotalSalesDollars"])*100,2)
data["StockTurnOver"]=round(data["TotalSalesQuantity"]/data["TotalPurchaseQuantity"],2)
data["SalesPurchaseRatio"]=round(data["TotalSalesDollars"]/data["TotalPurchaseDollars"],2)

# %%
data.head()
# Out:
#    Brand  VendorNumber  TotalPurchasePrice  TotalPurchaseQuantity  \
# 0     58          8320             5530.88                   3550
# 1     60         12546              717.80                   1633
# 2     61          8004              275.60                    312
# 3     62          1128            16255.89                   3200
# 4     63          1128            15961.04                   2855
#
#    TotalPurchaseDollars  VendorNo  TotalSalesDollars  TotalSalesQuantity  \
# 0               32944.0    8320.0           43341.54              3446.0
# 1               12084.2   12546.0           18716.25              1775.0
# 2                3307.2    8004.0            4364.88               312.0
# 3               91744.0    1128.0          119863.75              3125.0
# 4               86963.3    1128.0          112249.22              2778.0
#
#    ExciseTax               VendorName  FreightCost  \
# 0    2715.12  SHAW ROSS INT L IMP LTD      3151.92
# 1    1398.56  JIM BEAM BRANDS COMPANY    123880.97
# 2     245.70           SAZERAC CO INC     50293.62
# 3    2463.18        BROWN-FORMAN CORP     68601.68
# 4    2190.45        BROWN-FORMAN CORP     68601.68
#
#                    Description  PurchasePricePerUnit  ActualPricePerUnit  \
# 0  Gekkeikan Black & Gold Sake                  9.28               12.99
# 1       Canadian Club 1858 VAP                  7.40               10.99
# 2        Margaritaville Silver                 10.60               13.99
# 3     Herradura Silver Tequila                 28.67               36.99
# 4   Herradura Reposado Tequila                 30.46               38.99
#
#    GrossProfit  ProfitMargin  StockTurnOver  SalesPurchaseRatio
# 0     10397.54         23.99           0.97                1.32
# 1      6632.05         35.43           1.09                1.55
# 2      1057.68         24.23           1.00                1.32
# 3     28119.75         23.46           0.98                1.31
# 4     25285.92         22.53           0.97                1.29

# %%
data.to_csv("data/vendor_sales_data.csv")
